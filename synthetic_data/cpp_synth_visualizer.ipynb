# %% [markdown]
# This script takes result of CPP simulation like hits.txt and shows a heatmap

# %%
import matplotlib.pyplot as plt
from utils.hits_to_img import hits_to_img

img = hits_to_img("hits.txt")


plt.imshow(img)

# %%
img.save("detector_image.png")
