# %%
import matplotlib.pyplot as plt
from spot_utils import create_randomized_instance

full_img, core_only, center = create_randomized_instance()
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].imshow(full_img, cmap='gray')
axes[0].set_title("Full Synthetic Object")
axes[1].imshow(core_only, cmap='gray')
axes[1].set_title("Core Only")
axes[1].scatter(center[0], center[1], color='red', marker='x')

plt.show()
